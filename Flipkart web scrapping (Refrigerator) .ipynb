# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/refrigerators/pr?sid=j9e,abm,hzg"

# %%
url_req=requests.get(url)

# %%
url_req.status_code
# Out:
# 200

# %%
print(url_req.text)
# Out:
# <!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.
# ...

# %%
soup=BeautifulSoup(url_req.content,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
soup.title
# Out:
# <title>Refrigerators : Buy Fridges Online at Best Prices | Up to 75% Off | Flipkart</title>

# %%
soup.title.string
# Out:
# 'Refrigerators : Buy Fridges Online at Best Prices | Up to 75% Off | Flipkart'

# %%
soup.div
# Out:
# <div id="container"><div><div class="_1kfTjk"><div class="_1rH5Jn"><div class="_1TmfNK"></div><div class="_2Xfa2_"><div class="_3_C9Hx"><div class="_3qX0zy"><a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a><a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a></div></div><div class="_1cmsER"><form action="/search" class="_2M8cLY header-form-search" method="GET"><div class="col-12-12 _2oO9oE"><div class="_3OO5Xc"><input autocomplete="off" class="_3704LK" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/></div><button class="L0Z3Pu" type="submit"><svg class="" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg"><g fill="#287
# ...

# %%
soup.div.string

# %%
soup.a
# Out:
# <a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>

# %%
soup.find_all('a')
# Out:
# [<a href="/"><img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/></a>,
#  <a class="_21ljIi" href="/plus">Explore<!-- --> <span class="_2FVHGh">Plus</span><img src="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png" width="10"/></a>,
#  <a class="_1_3w1N" href="/account/login?ret=/refrigerators/pr%3Fsid%3Dj9e%2Cabm%2Chzg">Login</a>,
#  <a class="_3-PJz-" href="https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&amp;utm_medium=websitedirect"><span>Become a Seller</span></a>,
# ...

# %%
all_links=soup.find_all('a')
for r in all_links:
    print(r.get('href'))
# Out:
# /
# /plus
# /account/login?ret=/refrigerators/pr%3Fsid%3Dj9e%2Cabm%2Chzg
# https://seller.flipkart.com/sell-online/?utm_source=fkwebsite&utm_medium=websitedirect
# /viewcart?exploreMode=true&preference=FLIPKART
# /home-kitchen/pr?sid=j9e&otracker=categorytree
# /home-kitchen/home-appliances/pr?sid=j9e,abm&otracker=categorytree
# /refrigerators/pr?sid=j9e,abm,hzg&otracker=categorytree
# /buying-guide/refrigerators?sid=j9e,abm,hzg&otracker=bg_from_browse_lhs
# /
# /home-kitchen/pr?sid=j9e&marketplace=FLIPKART
# /home-kitchen/home-appliances/pr?sid=j9e,abm&marketplace=FLIPKART
# /refrigerators/pr?sid=j9e,abm,hzg&marketplace=FLIPKART
# http://seo.fkinternal.com/refrigerators/samsung~brand/pr?sid=j9e,abm,hzg
# http://seo.fkinternal.com/refrigerators/lg~brand/pr?sid=j9e,abm,hzg
# http://seo.fkinternal.com/refrigerators/haier~brand/pr?sid=j9e,abm,hzg
# http://seo.fkinternal.com/refrigerators/whirlpool~brand/pr?sid=j9e,abm,hzg
# ...

# %%
all_table=soup.find_all('table')

# %%
all_table
# Out:
# [<table border="1" cellpadding="1" cellspacing="1">
#  <tbody>
#  <tr>
#  <td>
#  <style type="text/css"><!--td {border: 1px solid #ccc;}br {mso-data-placement:same-cell;}-->
#  			</style>
#  <a href="/refrigerators/top-freezer-refrigerator~type/pr?sid=j9e%2Cabm%2Chzg">Top freezer Refrigerator</a></td>
#  <td>
#  <style type="text/css"><!--td {border: 1px solid #ccc;}br {mso-data-placement:same-cell;}-->
#  			</style>
#  <a href="/refrigerators/bottom-mount~type/pr?sid=j9e%2Cabm%2Chzg">Bottom Mount Refrigerator</a></td>
#  <td><a href="/refrigerators/cooling-unit~type/pr?sid=j9e%2Cabm%2Chzg">Cooling Unit Refrigerator</a></td>
#  <td><a href="/refrigerators/top-mount~type/pr?sid=j9e%2Cabm%2Chzg">Top Mount Refrigerator</a></td>
#  <td>
#  <style type="text/css"><!--td {border: 1px solid #ccc;}br {mso-data-placement:same-cell;}-->
#  			</style>
#  <a href="/refrigerators/side-by-side-refrigerator~type/pr?sid=j9e%2Cabm%2Chzg">Side by side Refrigerator</a></td>
#  </tr>
#  <tr>
# ...

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <head>\n  <link href="https://rukminim1.flixcart.com" rel="preconnect"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>\n  <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css" rel="stylesheet"/>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>\n  <meta content="102988293558" property="fb:page_id"/>\n  <meta content="658873552,624500995,100000233612389" property="fb:admins"/>\n  <meta content="noodp" name="robots"/>\n  <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>\n  <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>\n  <meta content="website" property="og:type"/>\n  <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>\n  <link href="/ap
# ...

# %%
model=soup.findAll('div',{'class':'_4rR01T'})

# %%
model
# Out:
# [<div class="_4rR01T">SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator</div>,
#  <div class="_4rR01T">Godrej 185 L Direct Cool Single Door 4 Star Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer</div>,
#  <div class="_4rR01T">Godrej 564 L Frost Free Side by Side Refrigerator</div>,
#  <div class="_4rR01T">Godrej 185 L Direct Cool Single Door 2 Star Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 253 L Frost Free Double Door 3 Star Convertible Refrigerator</div>,
#  <div class="_4rR01T">LG 260 L Frost Free Double Door Top Mount 3 Star Refrigerator  with Smart Inverter</div>,
#  <div class="_4rR01T">Whirlpool 190 L Direct Cool Single Door 2 Star Refrigerator</div>,
#  <div class="_4rR01T">SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator</div>,
#  <div class="_4rR01T">LG 260 L Frost Free Double Door Top Mount 3 Star Convertible Refrigerator  with Smart Inverter</div>,
# ...

# %%
product_name=[]
for i in model:
    p=i.text
    product_name.append(p)

# %%
print(product_name)
# Out:
# ['SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator', 'Godrej 185 L Direct Cool Single Door 4 Star Refrigerator', 'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer', 'Godrej 564 L Frost Free Side by Side Refrigerator', 'Godrej 185 L Direct Cool Single Door 2 Star Refrigerator', 'SAMSUNG 253 L Frost Free Double Door 3 Star Convertible Refrigerator', 'LG 260 L Frost Free Double Door Top Mount 3 Star Refrigerator  with Smart Inverter', 'Whirlpool 190 L Direct Cool Single Door 2 Star Refrigerator', 'SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator', 'LG 260 L Frost Free Double Door Top Mount 3 Star Convertible Refrigerator  with Smart Inverter', 'Whirlpool 240 L Frost Free Triple Door Refrigerator', 'Godrej 190 L Direct Cool Single Door 3 Star Refrigerator  with Intelligent Inverter Compressor', 'LG 190 L Direct Cool Single Door 5 Star Refrigerator with Base Drawer  with Smart Inverter Compressor', 'SAMSUNG 198 L Direct Cool Single Door 5 Star Re
# ...

# %%
len(product_name)
# Out:
# 24

# %%
type(product_name)
# Out:
# list

# %%
model_rating=soup.findAll('div',{'class':'_3LWZlK'})

# %%
model_rating
# Out:
# [<div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
# ...

# %%
product_rating=[]
for i in model_rating:
    r=i.text
    product_rating.append(r)

# %%
product_rating
# Out:
# ['4.4',
#  '4.3',
#  '4.5',
#  '4.7',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.5',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.4',
#  '3',
#  '1',
#  '4.7',
#  '5',
#  '5',
#  '4.3',
#  '5',
#  '4',
#  '4.3',
#  '5',
#  '1',
#  '4.4',
#  '5',
#  '4']

# %%
len(product_rating)
# Out:
# 39

# %%
type(product_rating)
# Out:
# list

# %%
model_price=soup.findAll('div',{'class':'_30jeq3 _1_WHN1'})

# %%
model_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹24,790</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,690</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹66,500</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,190</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹12,590</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,390</div>,
#  <div class="_30jeq3 _1_WHN1">₹26,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹25,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,790</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹17,290</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,490</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹36,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹19,990</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,690</div>,
#  <div class="_30jeq3 _1_WHN1">₹41,790</div>,
# ...

# %%
product_price = []
for i in model_price:
    pr=i.text
    product_price.append(pr)
    
print(product_price)
# Out:
# ['₹24,790', '₹14,690', '₹16,490', '₹66,500', '₹12,190', '₹26,290', '₹25,490', '₹12,590', '₹13,390', '₹26,290', '₹25,990', '₹13,790', '₹18,290', '₹17,990', '₹17,290', '₹16,490', '₹10,990', '₹36,990', '₹19,990', '₹15,690', '₹41,790', '₹15,790', '₹20,490', '₹15,990']

# %%
len(product_price)
# Out:
# 24

# %%
product_rating = product_rating[0:24]

# %%
len(product_rating)
# Out:
# 24

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = {'ProductName':product_name,'Price':product_price,'Rating':product_rating}

# %%
df
# Out:
# {'ProductName': ['SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator',
#   'Godrej 185 L Direct Cool Single Door 4 Star Refrigerator',
#   'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer',
#   'Godrej 564 L Frost Free Side by Side Refrigerator',
#   'Godrej 185 L Direct Cool Single Door 2 Star Refrigerator',
#   'SAMSUNG 253 L Frost Free Double Door 3 Star Convertible Refrigerator',
#   'LG 260 L Frost Free Double Door Top Mount 3 Star Refrigerator  with Smart Inverter',
#   'Whirlpool 190 L Direct Cool Single Door 2 Star Refrigerator',
#   'SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator',
#   'LG 260 L Frost Free Double Door Top Mount 3 Star Convertible Refrigerator  with Smart Inverter',
#   'Whirlpool 240 L Frost Free Triple Door Refrigerator',
#   'Godrej 190 L Direct Cool Single Door 3 Star Refrigerator  with Intelligent Inverter Compressor',
# ...

# %%
data = pd.DataFrame(df)
data
# Out:
#                                           ProductName    Price Rating
# 0   SAMSUNG 253 L Frost Free Double Door 3 Star Re...  ₹24,790    4.4
# 1   Godrej 185 L Direct Cool Single Door 4 Star Re...  ₹14,690    4.3
# 2   SAMSUNG 198 L Direct Cool Single Door 4 Star R...  ₹16,490    4.5
# 3   Godrej 564 L Frost Free Side by Side Refrigerator  ₹66,500    4.7
# 4   Godrej 185 L Direct Cool Single Door 2 Star Re...  ₹12,190    4.3
# 5   SAMSUNG 253 L Frost Free Double Door 3 Star Co...  ₹26,290    4.4
# 6   LG 260 L Frost Free Double Door Top Mount 3 St...  ₹25,490    4.4
# 7   Whirlpool 190 L Direct Cool Single Door 2 Star...  ₹12,590    4.3
# 8   SAMSUNG 192 L Direct Cool Single Door 2 Star R...  ₹13,390    4.4
# 9   LG 260 L Frost Free Double Door Top Mount 3 St...  ₹26,290    4.4
# 10  Whirlpool 240 L Frost Free Triple Door Refrige...  ₹25,990    4.4
# 11  Godrej 190 L Direct Cool Single Door 3 Star Re...  ₹13,790    4.3
# ...

# %% [markdown]
# ### EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df
# Out:
# {'ProductName': ['SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator',
#   'Godrej 185 L Direct Cool Single Door 4 Star Refrigerator',
#   'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer',
#   'Godrej 564 L Frost Free Side by Side Refrigerator',
#   'Godrej 185 L Direct Cool Single Door 2 Star Refrigerator',
#   'SAMSUNG 253 L Frost Free Double Door 3 Star Convertible Refrigerator',
#   'LG 260 L Frost Free Double Door Top Mount 3 Star Refrigerator  with Smart Inverter',
#   'Whirlpool 190 L Direct Cool Single Door 2 Star Refrigerator',
#   'SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator',
#   'LG 260 L Frost Free Double Door Top Mount 3 Star Convertible Refrigerator  with Smart Inverter',
#   'Whirlpool 240 L Frost Free Triple Door Refrigerator',
#   'Godrej 190 L Direct Cool Single Door 3 Star Refrigerator  with Intelligent Inverter Compressor',
# ...

# %%
data
# Out:
#                                           ProductName    Price Rating
# 0   SAMSUNG 253 L Frost Free Double Door 3 Star Re...  ₹24,790    4.4
# 1   Godrej 185 L Direct Cool Single Door 4 Star Re...  ₹14,690    4.3
# 2   SAMSUNG 198 L Direct Cool Single Door 4 Star R...  ₹16,490    4.5
# 3   Godrej 564 L Frost Free Side by Side Refrigerator  ₹66,500    4.7
# 4   Godrej 185 L Direct Cool Single Door 2 Star Re...  ₹12,190    4.3
# 5   SAMSUNG 253 L Frost Free Double Door 3 Star Co...  ₹26,290    4.4
# 6   LG 260 L Frost Free Double Door Top Mount 3 St...  ₹25,490    4.4
# 7   Whirlpool 190 L Direct Cool Single Door 2 Star...  ₹12,590    4.3
# 8   SAMSUNG 192 L Direct Cool Single Door 2 Star R...  ₹13,390    4.4
# 9   LG 260 L Frost Free Double Door Top Mount 3 St...  ₹26,290    4.4
# 10  Whirlpool 240 L Frost Free Triple Door Refrige...  ₹25,990    4.4
# 11  Godrej 190 L Direct Cool Single Door 3 Star Re...  ₹13,790    4.3
# ...

# %%
data.columns
# Out:
# Index(['ProductName', 'Price', 'Rating'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductName  24 non-null     object
#  1   Price        24 non-null     object
#  2   Rating       24 non-null     object
# dtypes: object(3)
# memory usage: 704.0+ bytes

# %%
data.describe()
# Out:
#                                               ProductName    Price Rating
# count                                                  24       24     24
# unique                                                 23       22      5
# top     Godrej 236 L Frost Free Double Door 2 Star Ref...  ₹16,490    4.3
# freq                                                    2        2     10

# %% [markdown]
#  ### Null Values

# %%
data.isnull()
# Out:
#     ProductName  Price  Rating
# 0         False  False   False
# 1         False  False   False
# 2         False  False   False
# 3         False  False   False
# 4         False  False   False
# 5         False  False   False
# 6         False  False   False
# 7         False  False   False
# 8         False  False   False
# 9         False  False   False
# 10        False  False   False
# 11        False  False   False
# 12        False  False   False
# 13        False  False   False
# 14        False  False   False
# 15        False  False   False
# 16        False  False   False
# 17        False  False   False
# 18        False  False   False
# 19        False  False   False
# 20        False  False   False
# 21        False  False   False
# 22        False  False   False
# 23        False  False   False

# %%
data.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     ProductName  Price  Rating
# 0         False  False   False
# 1         False  False   False
# 2         False  False   False
# 3         False  False   False
# 4         False  False   False
# 5         False  False   False
# 6         False  False   False
# 7         False  False   False
# 8         False  False   False
# 9         False  False   False
# 10        False  False   False
# 11        False  False   False
# 12        False  False   False
# 13        False  False   False
# 14        False  False   False
# 15        False  False   False
# 16        False  False   False
# 17        False  False   False
# 18        False  False   False
# 19        False  False   False
# 20        False  False   False
# 21        False  False   False
# 22        False  False   False
# 23        False  False   False>

# %%
data.head()
# Out:
#                                          ProductName    Price Rating
# 0  SAMSUNG 253 L Frost Free Double Door 3 Star Re...  ₹24,790    4.4
# 1  Godrej 185 L Direct Cool Single Door 4 Star Re...  ₹14,690    4.3
# 2  SAMSUNG 198 L Direct Cool Single Door 4 Star R...  ₹16,490    4.5
# 3  Godrej 564 L Frost Free Side by Side Refrigerator  ₹66,500    4.7
# 4  Godrej 185 L Direct Cool Single Door 2 Star Re...  ₹12,190    4.3

# %%
data.tail()
# Out:
#                                           ProductName    Price Rating
# 19  Whirlpool 190 L Direct Cool Single Door 3 Star...  ₹15,690    4.3
# 20  MarQ by Flipkart 468 L Frost Free Side by Side...  ₹41,790    4.3
# 21  Haier 195 L Direct Cool Single Door 5 Star Ref...  ₹15,790    4.4
# 22  Godrej 236 L Frost Free Double Door 2 Star Ref...  ₹20,490    4.3
# 23  Godrej 195 L Direct Cool Single Door 3 Star Re...  ₹15,990    4.3

# %% [markdown]
# ### To count number of categories

# %%
data['ProductName'].value_counts()
# Out:
# Godrej 236 L Frost Free Double Door 2 Star Refrigerator                                                      2
# SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator                                                     1
# LG 190 L Direct Cool Single Door 5 Star Refrigerator with Base Drawer  with Smart Inverter Compressor        1
# Haier 195 L Direct Cool Single Door 5 Star Refrigerator                                                      1
# MarQ by Flipkart 468 L Frost Free Side by Side Refrigerator                                                  1
# Whirlpool 190 L Direct Cool Single Door 3 Star Refrigerator with Base Drawer                                 1
# SAMSUNG 345 L Frost Free Double Door 3 Star Convertible Refrigerator                                         1
# CANDY 190 L Direct Cool Single Door 2 Star Refrigerator                                                      1
# ...

# %%
data['ProductName'].unique()
# Out:
# array(['SAMSUNG 253 L Frost Free Double Door 3 Star Refrigerator',
#        'Godrej 185 L Direct Cool Single Door 4 Star Refrigerator',
#        'SAMSUNG 198 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer',
#        'Godrej 564 L Frost Free Side by Side Refrigerator',
#        'Godrej 185 L Direct Cool Single Door 2 Star Refrigerator',
#        'SAMSUNG 253 L Frost Free Double Door 3 Star Convertible Refrigerator',
#        'LG 260 L Frost Free Double Door Top Mount 3 Star Refrigerator  with Smart Inverter',
#        'Whirlpool 190 L Direct Cool Single Door 2 Star Refrigerator',
#        'SAMSUNG 192 L Direct Cool Single Door 2 Star Refrigerator',
#        'LG 260 L Frost Free Double Door Top Mount 3 Star Convertible Refrigerator  with Smart Inverter',
#        'Whirlpool 240 L Frost Free Triple Door Refrigerator',
#        'Godrej 190 L Direct Cool Single Door 3 Star Refrigerator  with Intelligent Inverter Compressor',
# ...

# %% [markdown]
# ### pivot table

# %%
a1=data.copy()

# %%
a1=a1.pivot_table('Price',columns='ProductName',aggfunc='sum')

# %%
a1
# Out:
# ProductName CANDY 190 L Direct Cool Single Door 2 Star Refrigerator  \
# Price                                                  ₹10,990
#
# ProductName Godrej 185 L Direct Cool Single Door 2 Star Refrigerator  \
# Price                                                  ₹12,190
#
# ProductName Godrej 185 L Direct Cool Single Door 4 Star Refrigerator  \
# Price                                                  ₹14,690
#
# ProductName Godrej 190 L Direct Cool Single Door 3 Star Refrigerator  with Intelligent Inverter Compressor  \
# Price                                                  ₹13,790
#
# ProductName Godrej 190 L Direct Cool Single Door 5 Star Refrigerator  with Base Drawer and Intelligent Inverter Co...  \
# Price                                                  ₹16,490
#
# ProductName Godrej 195 L Direct Cool Single Door 3 Star Refrigerator with Base Drawer  \
# Price                                                  ₹15,990
#
# ...

# %%
plt.bar(data['Price'],data['Rating'])
plt.title('Price v/s Rating',fontsize=15,color='r')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ### count plot

# %%
plt.figure(figsize=(20,6))
sns.countplot(x=data['ProductName'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  ### conclusion

# %%
Godraj 234L has highest rating from rest of the other models.
